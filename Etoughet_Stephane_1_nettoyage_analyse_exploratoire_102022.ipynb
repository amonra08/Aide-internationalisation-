# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext google.colab.data_table
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %% [markdown]
# Dans le cadre de ce projet, je devais faire des analyses avec les critères de l'analyse PESTEL (PEST analysis).
#
# Les indicateurs retenus sont les suivants :
#
# -- Disponibilité alimentaire
#
# -- Macro-économiques
#
# -- Suivi de la population mondiale
#
# -- Stabilité politique

# %% [markdown]
# ## Librairies

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1 - Indicateur disponibilité alimentaire

# %%
# disponibilité alimentaire uniquement sur les volailles, (source : FAO)
dispo = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/P9/P9 _ Docs finals/dispo_poultry.csv")
dispo.head()
# Out:
#   Domain Code                 Domain  Area Code (M49)         Area  \
# 0         FBS  Food Balances (2010-)                4  Afghanistan
# 1         FBS  Food Balances (2010-)                4  Afghanistan
# 2         FBS  Food Balances (2010-)                4  Afghanistan
# 3         FBS  Food Balances (2010-)                4  Afghanistan
# 4         FBS  Food Balances (2010-)                4  Afghanistan
#
#    Element Code     Element Item Code (CPC)          Item  Year Code  Year  \
# 0          5511  Production           S2734  Poultry Meat       2015  2015
# 1          5511  Production           S2734  Poultry Meat       2016  2016
# 2          5511  Production           S2734  Poultry Meat       2017  2017
# 3          5511  Production           S2734  Poultry Meat       2018  2018
# 4          5511  Production           S2734  Poultry Meat       2019  2019
#
#           Unit  Value Flag Flag Description
# 0  1000 tonnes   25.0    I    Imputed value
# 1  1000 tonnes   24.0    I    Imputed value
# 2  1000 tonnes   28.0    I    Imputed value
# 3  1000 tonnes   29.0    I    Imputed value
# 4  1000 tonnes   28.0    I    Imputed value

# %%
dispo.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
dispo = dispo[['Area', 'Element', 'Item', 'Year', 'Value']]

dispo2 = dispo.pivot_table(index=["Area", "Year"], columns=["Element"])
dispo2.head()
# Out:
#                                     Value                  \
# Element          Domestic supply quantity Export Quantity
# Area        Year
# Afghanistan 2015                     66.0             0.0
#             2016                     69.0             NaN
#             2017                     64.0             NaN
#             2018                     53.0             0.0
#             2019                     67.0             NaN
#
#                                                            \
# Element          Fat supply quantity (g/capita/day)  Food
# Area        Year
# Afghanistan 2015                               0.42  66.0
#             2016                               0.42  69.0
#             2017                               0.38  64.0
#             2018                               0.31  53.0
#             2019                               0.38  67.0
#
#                                                 \
# Element          Food supply (kcal/capita/day)
# Area        Year
# Afghanistan 2015                           7.0
#             2016                           7.0
#             2017                           6.0
#             2018                           5.0
#             2019                           6.0
#
#                                                                              \
# Element          Food supply quantity (kg/capita/yr) Import Quantity Losses
# Area        Year
# Afghanistan 2015                                1.92            43.0    NaN
#             2016                                1.96            37.0    NaN
#             2017                                1.76            29.0    NaN
#             2018                                1.44            25.0    NaN
#             2019                                1.76            44.0    NaN
#
#                                                               \
# Element          Other uses (non-food) Processing Production
# Area        Year
# Afghanistan 2015                   NaN        NaN       25.0
#             2016                   NaN        NaN       24.0
#             2017                   NaN        NaN       28.0
#             2018                   NaN        NaN       29.0
#             2019                   NaN        NaN       28.0
#
#                                                                    \
# Element          Protein supply quantity (g/capita/day) Residuals
# Area        Year
# Afghanistan 2015                                   0.69       0.0
#             2016                                   0.70       0.0
#             2017                                   0.63       0.0
#             2018                                   0.51       0.0
#             2019                                   0.63       0.0
#
#
# Element          Stock Variation Tourist consumption
# Area        Year
# Afghanistan 2015             1.0                 NaN
#             2016            -8.0                 NaN
#             2017            -7.0                 NaN
#             2018             0.0                 NaN
#             2019             5.0                 NaN

# %%
t =dispo.pivot_table(index=["Area", "Year"], columns=["Element"])
r=[]
for i in t.columns:
    r.append(i[1])
r
# Out:
# ['Domestic supply quantity',
#  'Export Quantity',
#  'Fat supply quantity (g/capita/day)',
#  'Food',
#  'Food supply (kcal/capita/day)',
#  'Food supply quantity (kg/capita/yr)',
#  'Import Quantity',
#  'Losses',
#  'Other uses (non-food)',
#  'Processing',
#  'Production',
#  'Protein supply quantity (g/capita/day)',
#  'Residuals',
#  'Stock Variation',
#  'Tourist consumption']

# %%
dispo2.columns=['Domestic supply quantity',
 'Export Quantity',
 'Fat supply quantity (g/capita/day)',
 'Food',
 'Food supply (kcal/capita/day)',
 'Food supply quantity (kg/capita/yr)',
 'Import Quantity',
 'Losses',
 'Other uses (non-food)',
 'Processing',
 'Production',
 'Protein supply quantity (g/capita/day)',
 'Residuals',
 'Stock Variation',
 'Tourist consumption']

# %%
dispo2 = dispo2.reset_index()
dispo2
# Out:
#             Area  Year  Domestic supply quantity  Export Quantity  \
# 0    Afghanistan  2015                      66.0              0.0
# 1    Afghanistan  2016                      69.0              NaN
# 2    Afghanistan  2017                      64.0              NaN
# 3    Afghanistan  2018                      53.0              0.0
# 4    Afghanistan  2019                      67.0              NaN
# ..           ...   ...                       ...              ...
# 895     Zimbabwe  2015                      69.0              NaN
# 896     Zimbabwe  2016                      75.0              0.0
# 897     Zimbabwe  2017                      75.0              NaN
# 898     Zimbabwe  2018                      66.0              NaN
# 899     Zimbabwe  2019                      54.0              0.0
#
#      Fat supply quantity (g/capita/day)  Food  Food supply (kcal/capita/day)  \
# 0                                  0.42  66.0                            7.0
# 1                                  0.42  69.0                            7.0
# 2                                  0.38  64.0                            6.0
# 3                                  0.31  53.0                            5.0
# 4                                  0.38  67.0                            6.0
# ..                                  ...   ...                            ...
# 895                                1.06  69.0                           17.0
# 896                                1.13  75.0                           18.0
# 897                                1.11  75.0                           18.0
# 898                                0.97  66.0                           15.0
# 899                                0.77  54.0                           12.0
#
#      Food supply quantity (kg/capita/yr)  Import Quantity  Losses  \
# 0                                   1.92             43.0     NaN
# 1                                   1.96             37.0     NaN
# 2                                   1.76             29.0     NaN
# 3                                   1.44             25.0     NaN
# 4                                   1.76             44.0     NaN
# ..                                   ...              ...     ...
# 895                                 5.01              8.0     NaN
# 896                                 5.33              8.0     NaN
# 897                                 5.27              6.0     NaN
# 898                                 4.57              4.0     NaN
# 899                                 3.66              1.0     NaN
#
#      Other uses (non-food)  Processing  Production  \
# 0                      NaN         NaN        25.0
# 1                      NaN         NaN        24.0
# 2                      NaN         NaN        28.0
# 3                      NaN         NaN        29.0
# 4                      NaN         NaN        28.0
# ..                     ...         ...         ...
# 895                    NaN         NaN        61.0
# 896                    NaN         NaN        67.0
# 897                    NaN         NaN        69.0
# 898                    NaN         NaN        62.0
# 899                    NaN         NaN        52.0
#
#      Protein supply quantity (g/capita/day)  Residuals  Stock Variation  \
# 0                                      0.69        0.0              1.0
# 1                                      0.70        0.0             -8.0
# 2                                      0.63        0.0             -7.0
# 3                                      0.51        0.0              0.0
# 4                                      0.63        0.0              5.0
# ..                                      ...        ...              ...
# 895                                    1.69        0.0              0.0
# 896                                    1.80        0.0              0.0
# 897                                    1.78        0.0              0.0
# 898                                    1.54        0.0              0.0
# 899                                    1.23        0.0              0.0
#
#      Tourist consumption
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 895                  NaN
# 896                  NaN
# 897                  NaN
# 898                  NaN
# 899                  NaN
#
# [900 rows x 17 columns]

# %%
# On garde les données de l'année 2019
dispo2019 = dispo2[dispo2["Year"] == 2019]
dispo2019 = dispo2019.fillna(0)
dispo2019.head()
# Out:
#                    Area  Year  Domestic supply quantity  Export Quantity  \
# 4           Afghanistan  2019                      67.0              0.0
# 9               Albania  2019                      34.0              0.0
# 14              Algeria  2019                     287.0              1.0
# 19               Angola  2019                     327.0              0.0
# 24  Antigua and Barbuda  2019                       7.0              0.0
#
#     Fat supply quantity (g/capita/day)   Food  Food supply (kcal/capita/day)  \
# 4                                 0.38   67.0                            6.0
# 9                                 4.57   34.0                           61.0
# 14                                1.57  287.0                           23.0
# 19                                2.16  327.0                           34.0
# 24                               19.94    6.0                          265.0
#
#     Food supply quantity (kg/capita/yr)  Import Quantity  Losses  \
# 4                                  1.76             44.0     0.0
# 9                                 11.71             22.0     0.0
# 14                                 6.67              0.0     0.0
# 19                                10.28            278.0     0.0
# 24                                61.49              7.0     0.0
#
#     Other uses (non-food)  Processing  Production  \
# 4                     0.0         0.0        28.0
# 9                     0.0         0.0        12.0
# 14                    0.0         0.0       291.0
# 19                    0.0         0.0        49.0
# 24                    0.0         0.0         0.0
#
#     Protein supply quantity (g/capita/day)  Residuals  Stock Variation  \
# 4                                     0.63        0.0              5.0
# 9                                     4.54        0.0              0.0
# 14                                    2.06        0.0              2.0
# 19                                    3.49        0.0              0.0
# 24                                   20.17        0.0              0.0
#
#     Tourist consumption
# 4                   0.0
# 9                   0.0
# 14                  0.0
# 19                  0.0
# 24                  1.0

# %%
# Correction du nom de la Côte d'Ivoire
dispo2019["Area"].replace(["C?te d'Ivoire"],["Côte d'Ivoire"], inplace=True)

# %%
dispo2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 4 to 899
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Area                                    180 non-null    object
#  1   Year                                    180 non-null    int64
#  2   Domestic supply quantity                180 non-null    float64
#  3   Export Quantity                         180 non-null    float64
#  4   Fat supply quantity (g/capita/day)      180 non-null    float64
#  5   Food                                    180 non-null    float64
#  6   Food supply (kcal/capita/day)           180 non-null    float64
#  7   Food supply quantity (kg/capita/yr)     180 non-null    float64
#  8   Import Quantity                         180 non-null    float64
#  9   Losses                                  180 non-null    float64
#  10  Other uses (non-food)                   180 non-null    float64
#  11  Processing                              180 non-null    float64
#  12  Production                              180 non-null    float64
#  13  Protein supply quantity (g/capita/day)  180 non-null    float64
#  14  Residuals                               180 non-null    float64
#  15  Stock Variation                         180 non-null    float64
#  16  Tourist consumption                     180 non-null    float64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 25.3+ KB

# %% [markdown]
# Infos :
#
# Pour la suite de l'analyse, nous allons retenir un indiateur lié à la disponibilité alimentaire, à savoir :
#
# Import Quantity qui indique les quantités d'importation de volailes de chaque pays pour 2019.

# %%
dispo2019 = dispo2019[['Area','Import Quantity','Export Quantity','Production']]
dispo2019.head(10)
# Out:
#                    Area  Import Quantity  Export Quantity  Production
# 4           Afghanistan             44.0              0.0        28.0
# 9               Albania             22.0              0.0        12.0
# 14              Algeria              0.0              1.0       291.0
# 19               Angola            278.0              0.0        49.0
# 24  Antigua and Barbuda              7.0              0.0         0.0
# 29            Argentina              5.0            234.0      2248.0
# 34              Armenia             43.0              0.0        12.0
# 39            Australia              9.0             45.0      1278.0
# 44              Austria            113.0             87.0       132.0
# 49           Azerbaijan             39.0              1.0       112.0

# %% [markdown]
# ### 2 - Indicateurs macro-économiques

# %%
# source : FAO
gdp = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/P9/P9 _ Docs finals/FAO_GDP.csv")
gdp.head()
# Out:
#   Domain Code            Domain  Area Code (FAO)         Area  Element Code  \
# 0          MK  Macro Indicators                2  Afghanistan          6110
# 1          MK  Macro Indicators                2  Afghanistan          6119
# 2          MK  Macro Indicators                2  Afghanistan          6129
# 3          MK  Macro Indicators                2  Afghanistan         61290
# 4          MK  Macro Indicators                2  Afghanistan          6110
#
#                         Element  Item Code                    Item  Year Code  \
# 0                     Value US$      22008  Gross Domestic Product       2019
# 1          Value US$ per capita      22008  Gross Domestic Product       2019
# 2             Annual growth US$      22008  Gross Domestic Product       2019
# 3  Annual growth US$ per capita      22008  Gross Domestic Product       2019
# 4                     Value US$      22008  Gross Domestic Product       2020
#
#    Year      Unit         Value Flag                Flag Description  Note
# 0  2019  millions  18904.490263    X  International reliable sources   NaN
# 1  2019       US$    496.940553    X  International reliable sources   NaN
# 2  2019         %      2.636658   Fc                 Calculated data   NaN
# 3  2019         %      0.289848   Fc                 Calculated data   NaN
# 4  2020  millions  19793.262413    X  International reliable sources   NaN

# %%
# Sélection des données économiques de 2019
gdp["Item"] += " (" + gdp["Element"] + ")"
gdp2019= gdp[gdp["Year"] ==2019]
gdp2019 = pd.pivot_table(gdp2019, index="Area", columns="Item",values="Value")
gdp2019.columns =['GDP growth per capita (US$)',
       'GDP growth (US$)',
       'GDP per capita (US$)',
       'GDP (US$)']
gdp2019 = gdp2019.reset_index()

# %%
# Correction du nom Côte d'Ivoire
gdp2019["Area"].replace(["C?te d'Ivoire"],["Côte d'Ivoire"], inplace=True)

# %%
gdp2019.head().round(2)
# Out:
#           Area  GDP growth per capita (US$)  GDP growth (US$)  \
# 0  Afghanistan                         0.29              2.64
# 1      Albania                         1.67              1.61
# 2      Algeria                        -4.30             -2.43
# 3      Andorra                        -2.14             -1.97
# 4       Angola                       -14.59            -11.78
#
#    GDP per capita (US$)  GDP (US$)
# 0                496.94   18904.49
# 1               5345.60   15400.24
# 2               3975.52  171158.23
# 3              40900.54    3155.15
# 4               2809.63   89417.19

# %% [markdown]
# Pour mon analyse, je vais prendre les indicateurs macro économiques suivants:
#
# -- GDP per capita qui permet d'analyser la production de la richesse par habitant par pays,
#
# -- GDP growth per capita qui permet d'analyser la croissance du PIB par habitant sur plusieurs années

# %%
gdp2019 = gdp2019.drop(columns=["GDP growth (US$)", "GDP (US$)"])
gdp2019.head().round(2)
# Out:
#           Area  GDP growth per capita (US$)  GDP per capita (US$)
# 0  Afghanistan                         0.29                496.94
# 1      Albania                         1.67               5345.60
# 2      Algeria                        -4.30               3975.52
# 3      Andorra                        -2.14              40900.54
# 4       Angola                       -14.59               2809.63

# %%
# Merge 1
df = dispo2019.merge(gdp2019, on="Area", how="left")
df.head()
# Out:
#                   Area  Import Quantity  Export Quantity  Production  \
# 0          Afghanistan             44.0              0.0        28.0
# 1              Albania             22.0              0.0        12.0
# 2              Algeria              0.0              1.0       291.0
# 3               Angola            278.0              0.0        49.0
# 4  Antigua and Barbuda              7.0              0.0         0.0
#
#    GDP growth per capita (US$)  GDP per capita (US$)
# 0                     0.289848            496.940553
# 1                     1.672835           5345.602513
# 2                    -4.295718           3975.519002
# 3                   -14.591763           2809.626403
# 4                     4.180217          17376.112907

# %%
# Focus sur la Chine et ses territoires
df.loc[df["Area"]== "China, Taiwan Province of", ["GDP growth per capita (US$)","GDP per capita (US$)"] ] = df.loc[df["Area"]== "China, Macao SAR", ["GDP growth per capita (US$)","GDP per capita (US$)"]].values
df[df["Area"].str.contains("China")]
# Out:
#                          Area  Import Quantity  Export Quantity  Production  \
# 31                      China           1814.0            903.0     21195.0
# 32       China, Hong Kong SAR            773.0            310.0        19.0
# 33           China, Macao SAR             32.0              0.0         3.0
# 34  China, Taiwan Province of            215.0              5.0       731.0
# 35            China, mainland            795.0            588.0     20442.0
#
#     GDP growth per capita (US$)  GDP per capita (US$)
# 31                     2.275180          10195.736594
# 32                     0.234543          49179.751067
# 33                    -1.640253          86118.106459
# 34                    -1.640253          86118.106459
# 35                     2.331421           9959.637355

# %% [markdown]
# ### 3 - Indicateurs sociaux

# %%
# source : FAO
pop = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/P9/P9 _ Docs finals/FAO_POP.csv")

# %%
pop = pop[["Area", "Value"]]
pop.rename(columns={"2017":"Population (2017)","2018":"Population (2018)"}, inplace=True)
pop["Area"].replace(["C?te d'Ivoire"],["Côte d'Ivoire"], inplace=True)

# %%
pop.head()
# Out:
#              Area      Value
# 0     Afghanistan  37171.921
# 1         Albania   2882.740
# 2         Algeria  42228.408
# 3  American Samoa     55.465
# 4         Andorra     77.006

# %%
# Données FAO sur les populations de 2008 à 2019
pop = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/P9/P9 _ Docs finals/FAOSTAT_data_en_10-7-2022.csv")
pop = pop.pivot_table(index="Area",values="Value", columns="Year", aggfunc="sum")
pop.columns=["Population (2008)","Population (2009)","Population (2010)","Population (2011)","Population (2012)","Population (2013)","Population (2014)","Population (2015)","Population (2016)","Population (2017)","Population (2018)"]
pop = pop.reset_index()
pop["Area"].replace(["C?te d'Ivoire"],["Côte d'Ivoire"], inplace=True)

# %% [markdown]
# Le taux moyen de croissance de la population entre 2013 et 2018

# %%
pop["Avg. population growth (annual %)"] = round(((pop["Population (2018)"]/pop["Population (2013)"])**(1/5)*100)-100,2)
pop.head()
# Out:
#              Area  Population (2008)  Population (2009)  Population (2010)  \
# 0     Afghanistan          27722.276          28394.813          29185.507
# 1         Albania           3002.678           2973.048           2948.023
# 2         Algeria          34730.608          35333.881          35977.455
# 3  American Samoa             57.492             56.683             56.079
# 4         Andorra             83.862             84.463             84.449
#
#    Population (2011)  Population (2012)  Population (2013)  Population (2014)  \
# 0          30117.413          31161.376          32269.589          33370.794
# 1           2928.592           2914.096           2903.790           2896.305
# 2          36661.445          37383.895          38140.133          38923.692
# 3             55.759             55.667             55.713             55.791
# 4             83.747             82.427             80.774             79.213
#
#    Population (2015)  Population (2016)  Population (2017)  Population (2018)  \
# 0          34413.603          35383.032          36296.113          37171.921
# 1           2890.513           2886.438           2884.169           2882.740
# 2          39728.025          40551.392          41389.189          42228.408
# 3             55.812             55.741             55.620             55.465
# 4             78.011             77.297             77.001             77.006
#
#    Avg. population growth (annual %)
# 0                               2.87
# 1                              -0.15
# 2                               2.06
# 3                              -0.09
# 4                              -0.95

# %%
df = df.merge(pop[["Area","Avg. population growth (annual %)"]], on="Area", how="inner")

# %% [markdown]
# ### 4 - Indicateur stabilité politique

# %%
political = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/P9/P9 _ Docs finals/PoliticalStability.csv")
political = political[political["Year"]==2018]
political.rename(columns={"Country":"Area"}, inplace=True)
display(political.head())
political.info()
# Out:
#               Area  Year  Political_Stability Granularity
# 17     Afghanistan  2018                -2.75       Total
# 35         Albania  2018                 0.38       Total
# 53         Algeria  2018                -0.79       Total
# 68  American Samoa  2018                 1.21       Total
# 86         Andorra  2018                 1.43       Total
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 17 to 3525
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Area                 198 non-null    object
#  1   Year                 198 non-null    int64
#  2   Political_Stability  198 non-null    float64
#  3   Granularity          198 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 7.7+ KB

# %%
p = df.merge(political[["Area","Political_Stability"]],on="Area", how="outer", indicator=True)
p[p["_merge"] == "left_only"]
# Out:
#                  Area  Import Quantity  Export Quantity  Production  \
# 31              China           1814.0            903.0     21195.0
# 60   French Polynesia             17.0              0.0         1.0
# 116     New Caledonia             10.0              0.0         1.0
# 165           Türkiye             44.0            522.0      2202.0
#
#      GDP growth per capita (US$)  GDP per capita (US$)  \
# 31                      2.275180          10195.736594
# 60                     -2.650086          22078.072132
# 116                    -5.086060          33379.763021
# 165                          NaN                   NaN
#
#      Avg. population growth (annual %)  Political_Stability     _merge
# 31                                0.51                  NaN  left_only
# 60                                0.54                  NaN  left_only
# 116                               1.16                  NaN  left_only
# 165                               1.64                  NaN  left_only

# %%
df = df.merge(political[["Area","Political_Stability"]],on="Area", how="inner")
display(df.head())
df.info()
# Out:
#                   Area  Import Quantity  Export Quantity  Production  \
# 0          Afghanistan             44.0              0.0        28.0
# 1              Albania             22.0              0.0        12.0
# 2              Algeria              0.0              1.0       291.0
# 3               Angola            278.0              0.0        49.0
# 4  Antigua and Barbuda              7.0              0.0         0.0
#
#    GDP growth per capita (US$)  GDP per capita (US$)  \
# 0                     0.289848            496.940553
# 1                     1.672835           5345.602513
# 2                    -4.295718           3975.519002
# 3                   -14.591763           2809.626403
# 4                     4.180217          17376.112907
#
#    Avg. population growth (annual %)  Political_Stability
# 0                               2.87                -2.75
# 1                              -0.15                 0.38
# 2                               2.06                -0.79
# 3                               3.44                -0.32
# 4                               1.02                 0.73
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 0 to 175
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Area                               176 non-null    object
#  1   Import Quantity                    176 non-null    float64
#  2   Export Quantity                    176 non-null    float64
#  3   Production                         176 non-null    float64
#  4   GDP growth per capita (US$)        176 non-null    float64
#  5   GDP per capita (US$)               176 non-null    float64
#  6   Avg. population growth (annual %)  176 non-null    float64
#  7   Political_Stability                176 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 12.4+ KB

# %% [markdown]
# Infos :
#
# Pour la suite de l'analyse, nous allons retenir les deux indiateurs sociaux suivants :
#
# Avg. population growth c'est le taux de croissance moyen par an de la population sur cinq ans (2013 à 2018)
# Political stability afin d'avoir un aperçu sur la stabilité politique de chaque pays

# %%
region = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/P9/P9 _ Docs finals/country_grp.csv")
region.rename(columns={"Country":"Area", "Country Group":"Region"}, inplace=True)
region = region[region["Region"].isin(['Africa', 'Americas', 'Asia', 'Europe','Oceania',])]
df = df.merge(region[["Area", "Region"]], on="Area", how="left")
df.loc[df["Area"]== "Turkey", ["Region"]] = "Europe"

# %%
UE = ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden"]

df["Union european"] = 0
df["Union european"][df["Area"].isin(UE)] = 1

# %% [markdown]
# Infos :
#
# Pour la suite de l'analyse, nous allons retenir les deux indiateurs suivants :
#
# Region pour avoir l'information sur le continent de chaque pays.
# Union européenne pour distinguer les pays membres de l'UE.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 0 to 175
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Area                               176 non-null    object
#  1   Import Quantity                    176 non-null    float64
#  2   Export Quantity                    176 non-null    float64
#  3   Production                         176 non-null    float64
#  4   GDP growth per capita (US$)        176 non-null    float64
#  5   GDP per capita (US$)               176 non-null    float64
#  6   Avg. population growth (annual %)  176 non-null    float64
#  7   Political_Stability                176 non-null    float64
#  8   Region                             176 non-null    object
#  9   Union european                     176 non-null    int64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 15.1+ KB

# %% [markdown]
# ### **5 - Conclusion**
#
# Pour finir, nous avons retenus :
#
# deux indicateurs macro-économiques qui donnent des infomations sur la richesse du pays.
# deux indicateurs socio-économiques qui donnent des infos sur la roissance de la population et la stabilité politique du pays.
# deux indicateurs liés à la disponibilité alimentaire qui donnent des informations sur la consommation total du produit et les importations liés au produit.
# et deux critères qui donne des informations sur le continent et l'appartenance à l'Union européenne
# En total 8 indicateurs qui vont nous permettre de cibler les pays de manière éfficace

# %% [markdown]
# ### Export du dataset

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/P9/P9 _ Docs finals/df.csv", index=False)
